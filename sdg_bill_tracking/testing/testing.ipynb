# %%
from prefect_aws.s3 import S3Bucket
from prefect import flow, task
import pandas as pd
from io import BytesIO

@task(name = 'Connect S3')
def connect_s3(bucket = "portfolio-project-files"):
    s3 = S3Bucket.load(bucket)
    return s3

@task(name = 'Download S3 file')
def download_s3(s3, path):
    bytes = s3.read_path(path)
    data = pd.read_csv(BytesIO(bytes))
    return data

@task(name = 'Upload S3 file')
def upload_s3(s3, path, data):
    s3.write_path(path, bytes(data.to_csv(index=False), encoding='utf-8'))

@flow(name = 'test')
def master():
    s3 = connect_s3()
    data = download_s3(s3, 'sdg-bill-tracking/tagged_bills.csv')
    return data


data = master()
# Out:
# 19:31:16.221 | INFO    | Flow run 'strange-badger' - Beginning flow run 'strange-badger' for flow 'test'
# 19:31:16.224 | INFO    | Flow run 'strange-badger' - View at https://app.prefect.cloud/account/3f9bd1dc-a34b-4ba7-a6e0-e2aa163f25d6/workspace/4fe3e874-7162-4c73-879d-d1f78dbe5925/runs/flow-run/069af584-3df3-7fbe-8000-d2f8e98072d1
# 19:31:16.547 | INFO    | Task run 'Connect S3-b7e' - Finished in state Completed()
# 19:31:18.186 | INFO    | Task run 'Download S3 file-a3c' - Finished in state Completed()
# 19:31:18.409 | INFO    | Flow run 'strange-badger' - Finished in state Completed()

# %%
# 13742 Rows
data
# Out:
#                                           bill_file  \
# 0      US/2025-2026_119th_Congress/bill/HB7744.json
# 1      US/2025-2026_119th_Congress/bill/HB7745.json
# 2      US/2025-2026_119th_Congress/bill/HB7746.json
# 3      US/2025-2026_119th_Congress/bill/HB7747.json
# 4      US/2025-2026_119th_Congress/bill/HB7748.json
# ...                                             ...
# 13959  US/2025-2026_119th_Congress/bill/SJR104.json
# 13960  US/2025-2026_119th_Congress/bill/SJR105.json
# 13961  US/2025-2026_119th_Congress/bill/SJR106.json
# 13962  US/2025-2026_119th_Congress/bill/SJR107.json
# 13963  US/2025-2026_119th_Congress/bill/SJR108.json
#
#                            dataset_hash legislative_body  session_id  \
# 0      b572193bdeccd007e2e2dfb748663112               US        2199
# 1      b572193bdeccd007e2e2dfb748663112               US        2199
# 2      b572193bdeccd007e2e2dfb748663112               US        2199
# 3      b572193bdeccd007e2e2dfb748663112               US        2199
# 4      b572193bdeccd007e2e2dfb748663112               US        2199
# ...                                 ...              ...         ...
# 13959  b572193bdeccd007e2e2dfb748663112               US        2199
# 13960  b572193bdeccd007e2e2dfb748663112               US        2199
# 13961  b572193bdeccd007e2e2dfb748663112               US        2199
# 13962  b572193bdeccd007e2e2dfb748663112               US        2199
# 13963  b572193bdeccd007e2e2dfb748663112               US        2199
#
#          session_name bill_number                                       url  \
# 0      119th Congress      HB7744  https://legiscan.com/US/bill/HB7744/2025
# 1      119th Congress      HB7745  https://legiscan.com/US/bill/HB7745/2025
# 2      119th Congress      HB7746  https://legiscan.com/US/bill/HB7746/2025
# 3      119th Congress      HB7747  https://legiscan.com/US/bill/HB7747/2025
# 4      119th Congress      HB7748  https://legiscan.com/US/bill/HB7748/2025
# ...               ...         ...                                       ...
# 13959  119th Congress      SJR104  https://legiscan.com/US/bill/SJR104/2025
# 13960  119th Congress      SJR105  https://legiscan.com/US/bill/SJR105/2025
# 13961  119th Congress      SJR106  https://legiscan.com/US/bill/SJR106/2025
# 13962  119th Congress      SJR107  https://legiscan.com/US/bill/SJR107/2025
# 13963  119th Congress      SJR108  https://legiscan.com/US/bill/SJR108/2025
#
#            status status_date  \
# 0      Introduced  2026-03-02
# 1      Introduced  2026-03-02
# 2      Introduced  2026-03-02
# 3      Introduced  2026-03-02
# 4      Introduced  2026-03-02
# ...           ...         ...
# 13959  Introduced  2026-01-29
# 13960  Introduced  2026-02-04
# 13961  Introduced  2026-02-04
# 13962  Introduced  2026-02-12
# 13963  Introduced  2026-02-12
#
#                                                    title  \
# 0      Department of Homeland Security Appropriations...
# 1      To establish certain requirements relating to ...
# 2      To designate the facility of the United States...
# 3      To amend titles XVIII and XIX of the Social Se...
# 4      To enhance safety requirements for trains tran...
# ...                                                  ...
# 13959  A joint resolution to direct the removal of Un...
# 13960  A joint resolution redesignating the Robert E....
# 13961  A joint resolution providing for congressional...
# 13962  A joint resolution providing for congressional...
# 13963  A joint resolution providing for congressional...
#
#                                              description  \
# 0      Making appropriations for the Department of Ho...
# 1      To establish certain requirements relating to ...
# 2      To designate the facility of the United States...
# 3      To amend titles XVIII and XIX of the Social Se...
# 4      To enhance safety requirements for trains tran...
# ...                                                  ...
# 13959  A joint resolution to direct the removal of Un...
# 13960  A joint resolution redesignating the Robert E....
# 13961  A joint resolution providing for congressional...
# 13962  A joint resolution providing for congressional...
# 13963  A joint resolution providing for congressional...
#
#                                                 sponsors  tagged_sdgs  \
# 0                                       ['Tom Cole (R)']  [16, 11, 6]
# 1      ['Jodey Arrington (R)', 'Addison McDowell (R)'...          [3]
# 2                                    ['Wesley Bell (D)']           []
# 3      ['Jack Bergman (R)', 'Thomas Suozzi (D)', 'Bur...           []
# 4      ['Christopher Deluzio (D)', 'Nick LaLota (R)',...         [11]
# ...                                                  ...          ...
# 13959  ['Tim Kaine (D)', 'Rand Paul (R)', 'Charles Sc...           []
# 13960                                  ['Tim Kaine (D)']           []
# 13961                         ['Sheldon Whitehouse (D)']          [7]
# 13962  ['Catherine Cortez Masto (D)', 'Charles Schume...          [7]
# 13963                                  ['Rand Paul (R)']           []
#
#                 tagged_targets  tagged_targets_confidence
# 0      ['6.6', '16.4', '11.1']                        NaN
# 1        ['3.8', '3.c', '3.d']                        NaN
# 2                           []                        NaN
# 3                           []                        NaN
# 4                     ['11.2']                        NaN
# ...                        ...                        ...
# 13959                       []                        NaN
# 13960                       []                        NaN
# 13961                  ['7.a']                        NaN
# 13962                  ['7.a']                        NaN
# 13963                       []                        NaN
#
# [13964 rows x 15 columns]
